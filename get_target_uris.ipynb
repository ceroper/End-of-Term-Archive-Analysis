# %%
# data sourced from 
# https://archive.org/details/EndOfTerm2024PostInaugurationCrawls
# https://github.com/end-of-term

# %%
from warcio.archiveiterator import ArchiveIterator
import pandas as pd
from parse_uri_utils import *
import requests

# %%
resp = requests.get('https://archive.org/download/EOT24POST-20250426034535-crawl915/EOT24POST-20250426034535-27003.warc.gz', stream=True)

# %%
results = get_urls_and_resps(resp)

# %%
target_uris = [x for x in results if x[0] == 'target uri']

# %%
len(target_uris)
# Out:
# 4390
